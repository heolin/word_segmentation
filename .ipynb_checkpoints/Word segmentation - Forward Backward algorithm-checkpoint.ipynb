# %%
import math, sys
import base64
import zlib

# %%
freq_raw = """"""

# %%
def get_freq_list():
    freq_list = dict(map(lambda x:x.split('\t'), zlib.decompress(base64.decodestring(freq_raw)).split('\n')[:-1]))  
    freq_sum = float(sum(map(int, freq_list.values())))
    freq_list = {key:int(value)/freq_sum for key,value in freq_list.items()}
    return freq_list

# %%
def forward_step(input_text, freq_list):
    best_edge = [None for _ in range(1, len(input_text)+2)]
    best_score = [0 for _ in range(1, len(input_text)+2)]

    for word_end in range(1, len(input_text)+1):
        best_score[word_end] = 100000
        for word_begin in range(0, word_end):
            word = input_text[word_begin:word_end]
            if word in freq_list or len(word) == 1:
                prob = freq_list.get(word, 0.000001)
                my_score = best_score[word_begin] + -math.log(prob)
                #my_score += len(word) * 10000
                #print my_score,best_score[word_end]
                if my_score < best_score[word_end]:
                    best_score[word_end] = my_score
                    best_edge[word_end] = (word_begin, word_end)
    return best_edge

# %%
def backward_step(input_text, best_edge):
    words = []
    next_edge = best_edge[len(best_edge)-1]
    while next_edge != None:
        word = input_text[next_edge[0]:next_edge[1]]
        words.append(word)
        next_edge = best_edge[next_edge[0]]
    words.reverse()
    return words

# %%
def segment(input_text, freq_list):
    input_text = input_text.decode('utf-8')
    best_edge = forward_step(input_text, freq_list)
    words = backward_step(input_text, best_edge)
    return  " ".join(words)

# %%
freq_list = get_freq_list()
print segment("wearethepeople", freq_list)
print segment("mentionyourfaves", freq_list)
print segment("nowplaying", freq_list)
print segment("thewalkingdead", freq_list)
print segment("followme", freq_list)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-13-c27b2a24faa5> in <module>()
#       1 freq_list = get_freq_list()
# ----> 2 print segment("wearethepeople", freq_list)
#       3 print segment("mentionyourfaves", freq_list)
#       4 print segment("nowplaying", freq_list)
#       5 print segment("thewalkingdead", freq_list)
#
# <ipython-input-12-655ba9ac09a2> in segment(input_text, freq_list)
#       1 def segment(input_text, freq_list):
#       2     input_text = input_text.decode('utf-8')
# ----> 3     best_edge = forward_step(input_text, freq_list)
#       4     words = backward_step(input_text, best_edge)
#       5     return  " ".join(words)
#
# <ipython-input-10-01eddb992f1b> in forward_step(input_text, freq_list)
#      10                 prob = freq_list.get(word, 0.000001)
#      11                 F = best_score[word_begin] + -math.log(prob)
# ...

# %%
zlib.compress(base64.encodestring(freq_raw))
# Out:
# 'x\x9c\x1c\x9c\xddv\xaa:\x14F\xefy\x1a\x02\xd2\xb1\xbd,B@\x90XB~ w@\x1c\xa5\x10\x90*U\xe4\xe9\xcf\xf2\xdc\xedsv[!Y\xf9\xbe9\x95n\xc5\xe7]\xe5\xaa\xbe\t\x92S\xc6\x12\xd6b\xda7\xa2\xbbqg.yx\xbfQ$j:\xf9\xb7\x16\'O1\xd0\xe5"\xcd\xb5\r\xf4\x94K\xf2\xe0A\x87I(\xa6"\xf2\xb2K\xdf\xfdY\x19k\xdd\xac\'\n~\xe0\xa9\xb6\x8f\xab\xb6MR\xf5\x9f\xa8\xfe\x9ew\x99\x9b\xfc\x9c\xa5\x07/\x95\xd9\x8dcN\xc4%K\xdb\x93\x91l\x1d\xcb\xe2\xcai\xcb\x04\xd5\xd2{d\x1bIH\xa9\x8c\xa5\xf0\\\xa6\x8e\xb1\xb3\xed\xfb\xd9H\xe5\x91)\xd9\x98[\xbd\x94s\xdd\x1a\xac"1\xda\xaf\x86\x1d\x916t8\x07D\xaa\xc8C\x87\xd1s\xd8\x98\x08"\xe6(s\xa9!\xdbp\xa3\xd3<Z\x05\\Q;\xec?\xda\x119)\xea*\x15dO%\x93\xaf\n\xbe\xa15&jp\xf7C\xdc\xcaM\x91r\xe4D\xe5\xc5\xe4\xce\t}o\xbc\xac6\xb1\xe1\xbfv\xb0\xdd\xcbH\xec\xca\xe8\xca\xe2=O\x85Q\xf0\xd3\xdb\xad\t\xe0Vl\x84.?\x8b}\x8e\xbb]\xdd\xeb\x17\x1b\x15U\xd1\xf3!\x82\xefG6\xd1\x8e\xc5>\x93\xcc\xfc\xb2)w\x95\x1c\x1c-\xf7^\xc5\xc8OqX:+\x1b\xff\xbd\x88\xbd\xa2l\xca\xd7\xfag9\xc2\x9f\xcd\x99\xe1\nn\xe7u\xfe\xbc
# ...
